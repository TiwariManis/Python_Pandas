# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = '\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(2)
# Out:
#       order_id  quantity           item_name  \
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.info()



df.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# 4622

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# to save data as new file name

df.to_csv("New_df.csv")

# %%
a = df.groupby("order_id")
a = a.sum()
a = a.sort_values(['quantity'], ascending=False)

# %%
a.head(3)
# Out:
#           quantity
# order_id
# 1443            35
# 926             23
# 1786            20

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
#Turn the item price into a float

# %%
revenue = (df['quantity']* df['item_price']).sum()

print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-29-d24702c717c7> in <module>
#       1 revenue = (df['quantity']* df['item_price']).sum()
#       2
# ----> 3 print('Revenue was: $' + str(np.round(revenue,2)))
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3635     around : equivalent function; see for details.
#    3636     """
# -> 3637     return around(a, decimals=decimals, out=out)
#    3638
#    3639
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3260
#    3261     """
# -> 3262     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3263
#    3264
#
# ...

# %%
#print a data frame with only two columns item_name and item_price

# %%
df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# select only the products with quantity equals to 1

# %%
df1 = df[['item_name','quantity']]
df1
# Out:
#                                   item_name  quantity
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 4                              Chicken Bowl         2
# ...                                     ...       ...
# 4617                          Steak Burrito         1
# 4618                          Steak Burrito         1
# 4619                     Chicken Salad Bowl         1
# 4620                     Chicken Salad Bowl         1
# 4621                     Chicken Salad Bowl         1
#
# [4622 rows x 2 columns]

# %%
df2 = df1[df1.quantity == 1]
df2
# Out:
#                                   item_name  quantity
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 5                              Chicken Bowl         1
# ...                                     ...       ...
# 4617                          Steak Burrito         1
# 4618                          Steak Burrito         1
# 4619                     Chicken Salad Bowl         1
# 4620                     Chicken Salad Bowl         1
# 4621                     Chicken Salad Bowl         1
#
# [4355 rows x 2 columns]

# %%
#What was the quantity of the most expensive item ordered?

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df[df['item_price'] == max(df['item_price'])]
# Out:
#       order_id  quantity            item_name  \
# 607        250         1     Steak Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 2624      1042         1     Steak Salad Bowl
# 3098      1235         1     Steak Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3356      1346         1  Barbacoa Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4547      1807         1     Steak Salad Bowl
# 4572      1818         1     Steak Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
#How many times were a Veggie Salad Bowl ordered?

# %%
df[df.item_name == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt")

# %%
df3.head()
# Out:
#   name calories sodium alcohol cost
# 0         Budweiser 144 15 4.7 0.43
# 1           Schlitz 151 19 4.9 0.43
# 2         Lowenbrau 157 15 0.9 0.48
# 3        Kronenbourg 170 7 5.2 0.73
# 4          Heineken 152 11 5.0 0.77

# %%
df3.tail(2)
# Out:
#     name calories sodium alcohol cost
# 18  Olympia_Goled_Light 72 6 2.9 0.46
# 19        Schlitz_Light 97 7 4.2 0.47

# %%
df3.columns
# Out:
# Index(['name calories sodium alcohol cost'], dtype='object')

# %%
df4 = pd.DataFrame(df3)
df4
# Out:
#        name calories sodium alcohol cost
# 0              Budweiser 144 15 4.7 0.43
# 1                Schlitz 151 19 4.9 0.43
# 2              Lowenbrau 157 15 0.9 0.48
# 3             Kronenbourg 170 7 5.2 0.73
# 4               Heineken 152 11 5.0 0.77
# 5          Old_Milwaukee 145 23 4.6 0.28
# 6             Augsberger 175 24 5.5 0.40
# 7   Srohs_Bohemian_Style 149 27 4.7 0.42
# 8             Miller_Lite 99 10 4.3 0.43
# 9         Budweiser_Light 113 8 3.7 0.40
# 10                 Coors 140 18 4.6 0.44
# 11           Coors_Light 102 15 4.1 0.46
# 12        Michelob_Light 135 11 4.2 0.50
# 13                 Becks 150 19 4.7 0.76
# 14                  Kirin 149 6 5.0 0.79
# 15      Pabst_Extra_Light 68 15 2.3 0.38
# 16                 Hamms 139 19 4.4 0.43
# 17   Heilemans_Old_Style 144 24 4.9 0.43
# 18     Olympia_Goled_Light 72 6 2.9 0.46
# 19           Schlitz_Light 97 7 4.2 0.47

# %%
query = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"

df5 = pd.read_csv(query)

# %%
df5.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df5.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527

# %%
#Set the Year column as the index of the dataframe¶

# %%
set_index = df5.set_index('Year')
set_index.head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960              154320    912100        1855400         328200
# 1961              156760    949600        1913000         336000
# 1962              164570    994300        2089600         366800
# 1963              174210   1086400        2297800         408300
# 1964              203050   1213200        2514400         472800

# %%
#Return the first 3 rows of the DataFrame df5

# %%
df5[:3]
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800

# %%
df5.iloc[:3]
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df5.iloc[:3])
# Out:
# pandas.core.frame.DataFrame

# %%
#Select just the 'Murder' and 'Robbery' columns from the DataFrame df5 and print first and last five data

# %%
# 1st five data 

df5[["Murder","Robbery"]].head()
# Out:
#    Murder  Robbery
# 0    9110   107840
# 1    8740   106670
# 2    8530   110860
# 3    8640   116470
# 4    9360   130390

# %%
# last five data.

df5[["Murder","Robbery"]].tail()
# Out:
#     Murder  Robbery
# 50   14772   369089
# 51   14661   354772
# 52   14866   355051
# 53   14319   345095
# 54   14249   325802

# %%
# Otherway to find the above data 

df5.loc[:,["Murder","Robbery"]].head()
# Out:
#    Murder  Robbery
# 0    9110   107840
# 1    8740   106670
# 2    8530   110860
# 3    8640   116470
# 4    9360   130390

# %%
#Select the data in rows [3, 4, 8] and in columns ['Murder', 'Robbery']

# %%
df5.loc[df.index[[3,4,8]],["Murder","Robbery"]]
# Out:
#    Murder  Robbery
# 3    8640   116470
# 4    9360   130390
# 8   13800   262840

# %%
#Select only the rows where the number of murder is greater than 24,000

# %%
df5[df5["Murder"] > 24000]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# 33  1993   257908000  14144800  1926020  12218800   24530         106010
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 31   687730             1092740   3157200        8142200        1661700
# 33   659870             1135610   2834800        7820900        1563100

# %%
#Select the rows the murder is between 20k and 24k (inclusive)

# %%
df5[df5["Murder"].between(20000,24000)]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 14  1974   211392000  10253400   974720   9278700   20710          55400
# 15  1975   213124000  11292400  1039710  10252700   20510          56090
# 19  1979   220099000  12249500  1208030  11041500   21460          76390
# 20  1980   225349264  13408300  1344520  12063700   23040          82990
# 21  1981   229146000  13423800  1361820  12061900   22520          82500
# 22  1982   231534000  12974400  1322390  11652000   21010          78770
# 26  1986   240132887  13211869  1489169  11722700   20613          91459
# 27  1987   242282918  13508700  1483999  12024700   20096          91110
# 28  1988   245807000  13923100  1566220  12356900   20680          92490
# 29  1989   248239000  14251400  1646040  12605400   21500          94500
# 30  1990   248709873  14475600  1820130  12655500   23440         102560
# 32  1992   255082000  14438200  1932270  12505900   23760         109060
# ...

# %%
query = "https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv"
df6 = pd.read_csv(query)
df6.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
pd.Categorical(df6['Title'])
# Out:
# ['Fair's Extramarital Affairs Data', 'Consumer Price Index in Argentina', 'Bank Wages', 'Benderly and Zwick Data: Inflation, Growth an..., 'Bond Yield Data', ..., 'UK Soccer Scores', 'Visual Acuity in Left and Right Eyes', 'Von Bortkiewicz Horse Kicks Data', 'Weldon's Dice Data', 'Women in Queues']
# Length: 1714
# Categories (1580, object): ['"Let Them Watch TV"', ''May' in Federalist Papers', ''colors()' in Luv space', '100 m Swimming World Records', ..., 'sorption data set', 'titanic', 'titanicgrp', 'van Langren's Data on Longitude Distance betw...]

# %%
df6.describe()
# Out:
#                Rows         Cols     n_binary  n_character     n_factor  \
# count  1.714000e+03  1714.000000  1714.000000  1714.000000  1714.000000
# mean   3.900833e+03    13.086348     1.931155     0.302800     1.270128
# std    3.997025e+04   171.966384    17.416499     1.266075     3.194779
# min    2.000000e+00     1.000000     0.000000     0.000000     0.000000
# 25%    3.400000e+01     3.000000     0.000000     0.000000     0.000000
# 50%    1.055000e+02     5.000000     0.000000     0.000000     0.000000
# 75%    5.847500e+02     9.000000     2.000000     0.000000     2.000000
# max    1.414593e+06  6831.000000   624.000000    17.000000    64.000000
#
#          n_logical    n_numeric
# count  1714.000000  1714.000000
# mean      0.030922    11.429988
# std       0.405278   171.905339
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       0.000000     3.000000
# 75%       0.000000     7.000000
# max      11.000000  6830.000000
